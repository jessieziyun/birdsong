# %%
import sys
sys.path.append('../..')
from lib_train import *
# %matplotlib inline
# Out:
# {'sampling_rate': 16000, 'duration': 1, 'hop_length': 253, 'fmin': 20, 'fmax': 8000, 'n_mels': 64, 'n_fft': 1280, 'labels': ['AfricanPiedWagtail', 'BarnSwallow', 'BlackWoodpecker', 'BlackheadedGull', 'CanadaGoose', 'CarrionCrow', 'CoalTit', 'CommonBlackbird', 'CommonChaffinch', 'CommonChiffchaff', 'CommonCuckoo', 'CommonHouseMartin', 'CommonLinnet', 'CommonMoorhen', 'CommonNightingale', 'CommonPheasant', 'CommonRedpoll', 'CommonRedshank', 'CommonRedstart', 'CommonReedBunting', 'CommonSnipe', 'CommonStarling', 'CommonSwift', 'CommonWhitethroat', 'CommonWoodPigeon', 'CornBunting', 'Dunlin', 'Dunnock', 'EurasianBlackcap', 'EurasianBlueTit', 'EurasianBullfinch', 'EurasianCollaredDove', 'EurasianCoot', 'EurasianGreenfinch', 'EurasianJay', 'EurasianMagpie', 'EurasianNuthatch', 'EurasianOystercatcher', 'EurasianReedWarbler', 'EurasianSkylark', 'EurasianTreeSparrow', 'EurasianTreecreeper', 'EurasianWren', 'EurasianWryneck', 'EuropeanBeeEater', 'EuropeanGoldenPlover', 'EuropeanGoldfinch', 'EuropeanGreenWoodpecker', 'EuropeanHerringGull', 'EuropeanHoneyBuzzard', 'EuropeanNightjar', 'EuropeanRobin', 'EuropeanTurtleDove', 'GardenWarbler', 'Goldcrest', 'GoldenOriole', 'GreatSpottedWoodpecker', 'GreatTit', 'GreyPartridge', 'GreyPlover', 'HouseSparrow', 'LesserWhitethroat', 'LongTailedTit', 'MarshTit', 'MarshWarbler', 'MeadowPipit', 'NorthernLapwing', 'NorthernRaven', 'RedCrossbil', 'RedthroatedLoon', 'Redwing', 'RiverWarbler', 'RockDove', 'Rook', 'SedgeWarbler', 'SongThrush', 'SpottedFlycatcher', 'StockDove', 'TawnyOwl', 'TreePipit', 'WesternJackdaw', 'WesternYellowWagtail', 'WillowPtarmigan', 'WillowTit', 'WillowWarbler', 'WoodSandpiper', 'WoodWarbler', 'Yellowhammer'], 'folder': PosixPath('.'), 'n_fold': 1, 'normalize': 'samplewise', 'valid_limit': None, 'random_state': 42, 'samples_per_file': 30, 'test_size': 0.2, 'batch_size': 32, 'learning_rate': 0.0001, 'epochs': 50, 'verbose': 2, 'best_weight_file': 'best_model_weight.h5', 'eval_ensemble': False, 'rt_process_count': 1, 'rt_oversamples': 10, 'pred_ensembles': 10, 'runtime_model_file': 'cnn-model.pb', 'label2int': {'AfricanPiedWagtail': 0, 'BarnSwallow': 1, 'BlackWoodpecker': 2, 'BlackheadedGull': 3, 'CanadaGoose': 4, 'CarrionCrow': 5, 'CoalTit': 6, 'CommonBlackbird': 7, 'CommonChaffinch': 8, 'CommonChiffchaff': 9, 'CommonCuckoo': 10, 'CommonHouseMartin': 11, 'CommonLinnet': 12, 'CommonMoorhen': 13, 'CommonNightingale': 14, 'CommonPheasant': 15, 'CommonRedpoll': 16, 'CommonRedshank': 17, 'CommonRedstart': 18, 'CommonReedBunting': 19, 'CommonSnipe': 20, 'CommonStarling': 21, 'CommonSwift': 22, 'CommonWhitethroat': 23, 'CommonWoodPigeon': 24, 'CornBunting': 25, 'Dunlin': 26, 'Dunnock': 27, 'EurasianBlackcap': 28, 'EurasianBlueTit': 29, 'EurasianBullfinch': 30, 'EurasianCollaredDove': 31, 'EurasianCoot': 32, 'EurasianGreenfinch': 33, 'EurasianJay': 34, 'EurasianMagpie': 35, 'EurasianNuthatch': 36, 'EurasianOystercatcher': 37, 'EurasianReedWarbler': 38, 'EurasianSkylark': 39, 'EurasianTreeSparrow': 40, 'EurasianTreecreeper': 41, 'EurasianWren': 42, 'EurasianWryneck': 43, 'EuropeanBeeEater': 44, 'EuropeanGoldenPlover': 45, 'EuropeanGoldfinch': 46, 'EuropeanGreenWoodpecker': 47, 'EuropeanHerringGull': 48, 'EuropeanHoneyBuzzard': 49, 'EuropeanNightjar': 50, 'EuropeanRobin': 51, 'EuropeanTurtleDove': 52, 'GardenWarbler': 53, 'Goldcrest': 54, 'GoldenOriole': 55, 'GreatSpottedWoodpecker': 56, 'GreatTit': 57, 'GreyPartridge': 58, 'GreyPlover': 59, 'HouseSparrow': 60, 'LesserWhitethroat': 61, 'LongTailedTit': 62, 'MarshTit': 63, 'MarshWarbler': 64, 'MeadowPipit': 65, 'NorthernLapwing': 66, 'NorthernRaven': 67, 'RedCrossbil': 68, 'RedthroatedLoon': 69, 'Redwing': 70, 'RiverWarbler': 71, 'RockDove': 72, 'Rook': 73, 'SedgeWarbler': 74, 'SongThrush': 75, 'SpottedFlycatcher': 76, 'StockDove': 77, 'TawnyOwl': 78, 'TreePipit': 79, 'WesternJackdaw': 80, 'WesternYellowWagtail': 81, 'WillowPtarmigan': 82, 'WillowTit': 83, 'WillowWarbler': 84, 'WoodSandpiper': 85, 'WoodWarbler': 86, 'Yellowhammer': 87}, 'num ...
# Using TensorFlow backend.

# %%
DATAROOT = Path('./data/data')
data_files = list(DATAROOT.glob('*/*.wav'))
data_files
# Out:
# [PosixPath('data/data/CommonChaffinch/xc121597.wav'),
#  PosixPath('data/data/CommonChaffinch/xc42803.wav'),
#  PosixPath('data/data/CommonChaffinch/xc122548.wav'),
#  PosixPath('data/data/WesternYellowWagtail/xc69792.wav'),
#  PosixPath('data/data/WesternYellowWagtail/xc102788.wav'),
#  PosixPath('data/data/WesternYellowWagtail/xc36637.wav'),
#  PosixPath('data/data/Dunlin/xc64738.wav'),
#  PosixPath('data/data/Dunlin/xc83894.wav'),
#  PosixPath('data/data/Dunlin/xc118363.wav'),
#  PosixPath('data/data/Yellowhammer/xc102107.wav'),
#  PosixPath('data/data/Yellowhammer/xc102106.wav'),
#  PosixPath('data/data/Yellowhammer/xc145533.wav'),
#  PosixPath('data/data/WillowPtarmigan/xc71943.wav'),
#  PosixPath('data/data/WillowPtarmigan/xc130283.wav'),
#  PosixPath('data/data/WillowPtarmigan/xc149806.wav'),
#  PosixPath('data/data/EuropeanRobin/xc70124.wav'),
#  PosixPath('data/data/EuropeanRobin/xc133862.wav'),
#  PosixPath('data/data/EuropeanRobin/xc30390.wav'),
#  PosixPath('data/data/LongTailedTit/xc128853.wav'),
#  PosixPath('data/data/LongTailedTit/xc113082.wav'),
#  PosixPath('data/data/LongTailedTit/xc101371.wav'),
#  PosixPath('data/data/Goldcrest/xc49540.wav'),
#  PosixPath('data/data/Goldcrest/xc106846.wav'),
#  PosixPath('data/data/Goldcrest/xc78958.wav'),
#  PosixPath('data/data/MeadowPipit/xc142431.wav'),
#  PosixPath('data/data/MeadowPipit/xc30614.wav'),
#  PosixPath('data/data/MeadowPipit/xc138979.wav'),
#  PosixPath('data/data/TawnyOwl/xc67089.wav'),
#  PosixPath('data/data/TawnyOwl/xc64728.wav'),
#  PosixPath('data/data/TawnyOwl/xc76765.wav'),
#  PosixPath('data/data/SongThrush/xc96608.wav'),
#  PosixPath('data/data/SongThrush/xc132392.wav'),
#  PosixPath('data/data/SongThrush/xc146756.wav'),
#  PosixPath('data/data/CommonRedshank/xc57919.wav'),
#  PosixPath('data/data/CommonRedshank/xc110167.wav'),
#  PosixPath('data/data/CommonRedshank/xc83912.wav'),
#  PosixPath('data/data/LesserWhitethroat/xc101932.wav'),
#  PosixPath('data/data/LesserWhitethroat/xc102278.wav'),
#  PosixPath('data/data/LesserWhitethroat/xc101933.wav'),
#  PosixPath('data/data/CommonRedstart/xc76762.wav'),
#  PosixPath('data/data/CommonRedstart/xc76760.wav'),
#  PosixPath('data/data/CommonRedstart/xc76761.wav'),
#  PosixPath('data/data/WesternJackdaw/xc121735.wav'),
#  PosixPath('data/data/WesternJackdaw/xc156262.wav'),
#  PosixPath('data/data/WesternJackdaw/xc121691.wav'),
#  PosixPath('data/data/EurasianCoot/xc31059.wav'),
#  PosixPath('data/data/EurasianCoot/xc44707.wav'),
#  PosixPath('data/data/EurasianCoot/xc130639.wav'),
#  PosixPath('data/data/CommonBlackbird/xc94958.wav'),
#  PosixPath('data/data/CommonBlackbird/xc127996.wav'),
#  PosixPath('data/data/CommonBlackbird/xc72861.wav'),
#  PosixPath('data/data/CommonSwift/xc77645.wav'),
#  PosixPath('data/data/CommonSwift/xc139552.wav'),
#  PosixPath('data/data/CommonSwift/xc67307.wav'),
#  PosixPath('data/data/RiverWarbler/xc83760.wav'),
#  PosixPath('data/data/RiverWarbler/xc110303.wav'),
#  PosixPath('data/data/RiverWarbler/xc140557.wav'),
#  PosixPath('data/data/EuropeanBeeEater/xc148426.wav'),
#  PosixPath('data/data/EuropeanBeeEater/xc141026.wav'),
#  PosixPath('data/data/EuropeanBeeEater/xc97194.wav'),
#  PosixPath('data/data/EurasianCollaredDove/xc128851.wav'),
#  PosixPath('data/data/EurasianCollaredDove/xc101940.wav'),
#  PosixPath('data/data/EurasianCollaredDove/xc101941.wav'),
#  PosixPath('data/data/GreatSpottedWoodpecker/xc98172.wav'),
#  PosixPath('data/data/GreatSpottedWoodpecker/xc148528.wav'),
#  PosixPath('data/data/GreatSpottedWoodpecker/xc72629.wav'),
#  PosixPath('data/data/GardenWarbler/xc146260.wav'),
#  PosixPath('data/data/GardenWarbler/xc102932.wav'),
#  PosixPath('data/data/GardenWarbler/xc49443.wav'),
#  PosixPath('data/data/CommonStarling/xc101936.wav'),
#  PosixPath('data/data/CommonStarling/xc42698.wav'),
#  PosixPath('data/data/CommonStarling/xc144382.wav'),
#  PosixPath('data/data/EurasianTreeSparrow/xc43764.wav'),
#  PosixPath('data/data/EurasianTreeSparrow/xc143465.wav'),
#  PosixPath('data/data/EurasianTreeSparrow/xc90122.wav'),
#  PosixPath('data/data/CommonHouseMartin/xc142697.wav'),
#  PosixPath('data/data/CommonHouseMartin/xc133444.wav'),
#  PosixPath('data/data/CommonHouseMartin/xc148465.wav'),
#  PosixPath('data/data/CommonSnipe/xc135270.wav'),
#  PosixPath('data/data/CommonSnipe/xc90977.wav'),
#  PosixPath('data/data/CommonSnipe/xc27080.wav'),
#  PosixPath('data/data/WillowWarbler/xc146755.wav'),
#  PosixPath('data/data/WillowWarbler/xc121601.wav'),
#  PosixPath('data/data/WillowWarbler/xc99529.wav'),
#  PosixPath('data/data/EurasianBlackcap/xc94964.wav'),
#  PosixPath('data/data/EurasianBlackcap/xc94967.wav'),
#  PosixPath('data/data/EurasianBlackcap/xc99357.wav'),
#  PosixPath('data/data/CommonChiffchaff/xc121963.wav'),
#  PosixPath('data/data/CommonChiffchaff/xc153833.wav'),
#  PosixPath('data/data/CommonChiffchaff/xc71748.wav'),
#  PosixPath('data/data/TreePipit/xc83705.wav'),
#  PosixPath('data/data/TreePipit/xc33395.wav'),
#  PosixPath('data/data/TreePipit/xc99299.wav'),
#  PosixPath('data/data/Dunnock/xc145537.wav'),
#  PosixPath('data/data/Dunnock/xc70132.wav'),
#  PosixPath('data/data/Dunnock/xc94669.wav'),
#  PosixPath('data/data/MarshWarbler/xc64686.wav'),
#  PosixPath('data/data/MarshWarbler/xc82715.wav'),
#  PosixPath('data/data/MarshWarbler/xc64685.wav'),
#  PosixPath('data/data/WoodSandpiper/xc102869.wav'),
#  PosixPath('data/data/WoodSandpiper/xc102868.wav'),
#  PosixPath('data/data/WoodSandpiper/xc41816.wav'),
#  PosixPath('data/data/MarshTit/xc55184.wav'),
#  PosixPath('data/data/MarshTit/xc26578.wav'),
#  PosixPath('data/data/MarshTit/xc46032.wav'),
#  PosixPath('data/data/BlackheadedGull/xc129576.wav'),
#  PosixPath('data/data/BlackheadedGull/xc129577.wav'),
#  PosixPath('data/data/BlackheadedGull/xc143894.wav'),
#  PosixPath('data/data/CommonRedpoll/xc35068.wav'),
#  PosixPath('data/data/CommonRedpoll/xc132611.wav'),
#  PosixPath('data/data/CommonRedpoll/xc132608.wav'),
#  PosixPath('data/data/SedgeWarbler/xc120666.wav'),
#  PosixPath('data/data/SedgeWarbler/xc120664.wav'),
#  PosixPath('data/data/SedgeWarbler/xc76767.wav'),
#  PosixPath('data/data/WoodWarbler/xc101862.wav'),
#  PosixPath('data/data/WoodWarbler/xc101934.wav'),
#  PosixPath('data/data/WoodWarbler/xc101935.wav'),
#  PosixPath('data/data/CoalTit/xc98842.wav'),
#  PosixPath('data/data/CoalTit/xc132149.wav'),
#  PosixPath('data/data/CoalTit/xc95058.wav'),
#  PosixPath('data/data/EurasianBlueTit/xc42178.wav'),
#  PosixPath('data/data/EurasianBlueTit/xc131316.wav'),
#  PosixPath('data/data/EurasianBlueTit/xc44203.wav'),
#  PosixPath('data/data/NorthernRaven/xc64735.wav'),
#  PosixPath('data/data/NorthernRaven/xc143170.wav'),
#  PosixPath('data/data/NorthernRaven/xc42224.wav'),
#  PosixPath('data/data/GreyPartridge/xc42430.wav'),
#  PosixPath('data/data/GreyPartridge/xc46209.wav'),
#  PosixPath('data/data/GreyPartridge/xc46211.wav'),
#  PosixPath('data/data/EuropeanNightjar/xc27039.wav'),
#  PosixPath('data/data/EuropeanNightjar/xc156388.wav'),
#  PosixPath('data/data/EuropeanNightjar/xc67229.wav'),
#  PosixPath('data/data/GreyPlover/xc146757.wav'),
#  PosixPath('data/data/GreyPlover/xc150291.wav'),
#  PosixPath('data/data/GreyPlover/xc160879.wav'),
#  PosixPath('data/data/CommonPheasant/xc121326.wav'),
#  PosixPath('data/data/CommonPheasant/xc153129.wav'),
#  PosixPath('data/data/CommonPheasant/xc149146.wav'),
#  PosixPath('data/data/EurasianWryneck/xc133471.wav'),
#  PosixPath('data/data/EurasianWryneck/xc108002.wav'),
#  PosixPath('data/data/EurasianWryneck/xc133054.wav'),
#  PosixPath('data/data/CanadaGoose/xc95381.wav'),
#  PosixPath('data/data/CanadaGoose/xc94584.wav'),
#  PosixPath('data/data/CanadaGoose/xc35578.wav'),
#  PosixPath('data/data/EuropeanGreenWoodpecker/xc153131.wav'),
#  PosixPath('data/data/EuropeanGreenWoodpecker/xc43853.wav'),
#  PosixPath('data/data/EuropeanGreenWoodpecker/xc99072.wav'),
#  PosixPath('data/data/CommonWhitethroat/xc76742.wav'),
#  PosixPath('data/data/CommonWhitethroat/xc135521.wav'),
#  PosixPath('data/data/CommonWhitethroat/xc76740.wav'),
#  PosixPath('data/data/NorthernLapwing/xc27060.wav'),
#  PosixPath('data/data/NorthernLapwing/xc69855.wav'),
#  PosixPath('data/data/NorthernLapwing/xc97982.wav'),
#  PosixPath('data/data/Rook/xc143005.wav'),
#  PosixPath('data/data/Rook/xc143002.wav'),
#  PosixPath('data/data/Rook/xc27145.wav'),
#  PosixPath('data/data/CommonReedBunting/xc102803.wav'),
#  PosixPath('data/data/CommonReedBunting/xc86327.wav'),
#  PosixPath('data/data/CommonReedBunting/xc102048.wav'),
#  PosixPath('data/data/WillowTit/xc98691.wav'),
#  PosixPath('data/data/WillowTit/xc164926.wav'),
#  PosixPath('data/data/WillowTit/xc91185.wav'),
#  PosixPath('data/data/Redwing/xc121168.wav'),
#  PosixPath('data/data/Redwing/xc25119.wav'),
#  PosixPath('data/data/Redwing/xc27962.wav'),
#  PosixPath('data/data/SpottedFlycatcher/xc103145.wav'),
#  PosixPath('data/data/SpottedFlycatcher/xc139372.wav'),
#  PosixPath('data/data/SpottedFlycatcher/xc134042.wav'),
#  PosixPath('data/data/EuropeanHerringGull/xc125486.wav'),
#  PosixPath('data/data/EuropeanHerringGull/xc154285.wav'),
#  PosixPath('data/data/EuropeanHerringGull/xc126481.wav'),
#  PosixPath('data/data/EuropeanHoneyBuzzard/xc146062.wav'),
#  PosixPath('data/data/EuropeanHoneyBuzzard/xc145738.wav'),
#  PosixPath('data/data/EuropeanHoneyBuzzard/xc113089.wav'),
#  PosixPath('data/data/EurasianBullfinch/xc113905.wav'),
#  PosixPath('data/data/EurasianBullfinch/xc83357.wav'),
#  PosixPath('data/data/EurasianBullfinch/xc146707.wav'),
#  PosixPath('data/data/RedCrossbil/xc94212.wav'),
#  PosixPath('data/data/RedCrossbil/xc94211.wav'),
#  PosixPath('data/data/RedCrossbil/xc99862.wav'),
#  PosixPath('data/data/GreatTit/xc71454.wav'),
#  PosixPath('data/data/GreatTit/xc94652.wav'),
#  PosixPath('data/data/GreatTit/xc122555.wav'),
#  PosixPath('data/data/GoldenOriole/xc80356.wav'),
#  PosixPath('data/data/GoldenOriole/xc27152.wav'),
#  PosixPath('data/data/GoldenOriole/xc101377.wav'),
#  PosixPath('data/data/EurasianGreenfinch/xc124013.wav'),
#  PosixPath('data/data/EurasianGreenfinch/xc99155.wav'),
#  PosixPath('data/data/EurasianGreenfinch/xc28961.wav'),
#  PosixPath('data/data/EurasianNuthatch/xc78951.wav'),
#  PosixPath('data/data/EurasianNuthatch/xc28926.wav'),
#  PosixPath('data/data/EurasianNuthatch/xc99937.wav'),
#  PosixPath('data/data/EuropeanGoldfinch/xc133880.wav'),
#  PosixPath('data/data/EuropeanGoldfinch/xc133886.wav'),
#  PosixPath('data/data/EuropeanGoldfinch/xc97792.wav'),
#  PosixPath('data/data/BarnSwallow/xc157279.wav'),
#  PosixPath('data/data/BarnSwallow/xc157322.wav'),
#  PosixPath('data/data/BarnSwallow/xc157331.wav'),
#  PosixPath('data/data/CommonCuckoo/xc37447.wav'),
#  PosixPath('data/data/CommonCuckoo/xc33392.wav'),
#  PosixPath('data/data/CommonCuckoo/xc134671.wav'),
#  PosixPath('data/data/CommonMoorhen/xc26789.wav'),
#  PosixPath('data/data/CommonMoorhen/xc89530.wav'),
#  PosixPath('data/data/CommonMoorhen/xc82701.wav'),
#  PosixPath('data/data/CornBunting/xc125777.wav'),
#  PosixPath('data/data/CornBunting/xc123168.wav'),
#  PosixPath('data/data/CornBunting/xc123167.wav'),
#  PosixPath('data/data/BlackWoodpecker/xc130426.wav'),
#  PosixPath('data/data/BlackWoodpecker/xc155975.wav'),
#  PosixPath('data/data/BlackWoodpecker/xc98942.wav'),
#  PosixPath('data/data/CommonWoodPigeon/xc94614.wav'),
#  PosixPath('data/data/CommonWoodPigeon/xc130993.wav'),
#  PosixPath('data/data/CommonWoodPigeon/xc94615.wav'),
#  PosixPath('data/data/CommonLinnet/xc102060.wav'),
#  PosixPath('data/data/CommonLinnet/xc145534.wav'),
#  PosixPath('data/data/CommonLinnet/xc125782.wav'),
#  PosixPath('data/data/HouseSparrow/xc134291.wav'),
#  PosixPath('data/data/HouseSparrow/xc29766.wav'),
#  PosixPath('data/data/HouseSparrow/xc151150.wav'),
#  PosixPath('data/data/EuropeanTurtleDove/xc144991.wav'),
#  PosixPath('data/data/EuropeanTurtleDove/xc75092.wav'),
#  PosixPath('data/data/EuropeanTurtleDove/xc40186.wav'),
#  PosixPath('data/data/EurasianJay/xc142908.wav'),
#  PosixPath('data/data/EurasianJay/xc127136.wav'),
#  PosixPath('data/data/EurasianJay/xc46223.wav'),
#  PosixPath('data/data/EurasianMagpie/xc148889.wav'),
#  PosixPath('data/data/EurasianMagpie/xc29230.wav'),
#  PosixPath('data/data/EurasianMagpie/xc121016.wav'),
#  PosixPath('data/data/RedthroatedLoon/xc58579.wav'),
#  PosixPath('data/data/RedthroatedLoon/xc58573.wav'),
#  PosixPath('data/data/RedthroatedLoon/xc58571.wav'),
#  PosixPath('data/data/RockDove/xc121677.wav'),
#  PosixPath('data/data/RockDove/xc116226.wav'),
#  PosixPath('data/data/RockDove/xc92264.wav'),
#  PosixPath('data/data/EurasianOystercatcher/xc76241.wav'),
#  PosixPath('data/data/EurasianOystercatcher/xc53817.wav'),
#  PosixPath('data/data/EurasianOystercatcher/xc25754.wav'),
#  PosixPath('data/data/CommonNightingale/xc132580.wav'),
#  PosixPath('data/data/CommonNightingale/xc123810.wav'),
#  PosixPath('data/data/CommonNightingale/xc123808.wav'),
#  PosixPath('data/data/EurasianSkylark/xc123169.wav'),
#  PosixPath('data/data/EurasianSkylark/xc123170.wav'),
#  PosixPath('data/data/EurasianSkylark/xc158166.wav'),
#  PosixPath('data/data/EuropeanGoldenPlover/xc85842.wav'),
#  PosixPath('data/data/EuropeanGoldenPlover/xc42343.wav'),
#  PosixPath('data/data/EuropeanGoldenPlover/xc42344.wav'),
#  PosixPath('data/data/AfricanPiedWagtail/xc125137.wav'),
#  PosixPath('data/data/AfricanPiedWagtail/xc118441.wav'),
#  PosixPath('data/data/AfricanPiedWagtail/xc41428.wav'),
#  PosixPath('data/data/CarrionCrow/xc96464.wav'),
#  PosixPath('data/data/CarrionCrow/xc98400.wav'),
#  PosixPath('data/data/CarrionCrow/xc96133.wav'),
#  PosixPath('data/data/EurasianTreecreeper/xc146753.wav'),
#  PosixPath('data/data/EurasianTreecreeper/xc70129.wav'),
#  PosixPath('data/data/EurasianTreecreeper/xc130409.wav'),
#  PosixPath('data/data/StockDove/xc77429.wav'),
#  PosixPath('data/data/StockDove/xc89994.wav'),
#  PosixPath('data/data/StockDove/xc82971.wav'),
#  PosixPath('data/data/EurasianReedWarbler/xc27999.wav'),
#  PosixPath('data/data/EurasianReedWarbler/xc124053.wav'),
#  PosixPath('data/data/EurasianReedWarbler/xc124052.wav'),
#  PosixPath('data/data/EurasianWren/xc133872.wav'),
#  PosixPath('data/data/EurasianWren/xc71024.wav'),
#  PosixPath('data/data/EurasianWren/xc59776.wav')]

# %%
# 1. generate XX and y
XX = mels_build_multiplexed_X(conf, data_files)
y, _, _ = generate_y_from_pathname(data_files)

# 2. flatten (= unseen data is not available) & shuffle by train_test_split
X, y = mels_demux_XX_y(XX, y) # demultiplex = flatten
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=conf.test_size, random_state=conf.random_state)

# 3. write all sets as files
np.save('X_train.npy', X_train)
np.save('y_train.npy', y_train)
np.save('X_test.npy', X_test)
np.save('y_test.npy', y_test)

print('Training set has {} samples. X shape is {}'.format(len(X_train), X_train.shape))
print('Test set has {} samples. X shape is {}'.format(len(X_test), X_test.shape))
# Out:
# Set labels to config.py; conf.labels = ['AfricanPiedWagtail', 'BarnSwallow', 'BlackWoodpecker', 'BlackheadedGull', 'CanadaGoose', 'CarrionCrow', 'CoalTit', 'CommonBlackbird', 'CommonChaffinch', 'CommonChiffchaff', 'CommonCuckoo', 'CommonHouseMartin', 'CommonLinnet', 'CommonMoorhen', 'CommonNightingale', 'CommonPheasant', 'CommonRedpoll', 'CommonRedshank', 'CommonRedstart', 'CommonReedBunting', 'CommonSnipe', 'CommonStarling', 'CommonSwift', 'CommonWhitethroat', 'CommonWoodPigeon', 'CornBunting', 'Dunlin', 'Dunnock', 'EurasianBlackcap', 'EurasianBlueTit', 'EurasianBullfinch', 'EurasianCollaredDove', 'EurasianCoot', 'EurasianGreenfinch', 'EurasianJay', 'EurasianMagpie', 'EurasianNuthatch', 'EurasianOystercatcher', 'EurasianReedWarbler', 'EurasianSkylark', 'EurasianTreeSparrow', 'EurasianTreecreeper', 'EurasianWren', 'EurasianWryneck', 'EuropeanBeeEater', 'EuropeanGoldenPlover', 'EuropeanGoldfinch', 'EuropeanGreenWoodpecker', 'EuropeanHerringGull', 'EuropeanHoneyBuzzard', 'EuropeanNightjar', 'EuropeanRobin', 'EuropeanTurtleDove', 'GardenWarbler', 'Goldcrest', 'GoldenOriole', 'GreatSpottedWoodpecker', 'GreatTit', 'GreyPartridge', 'GreyPlover', 'HouseSparrow', 'LesserWhitethroat', 'LongTailedTit', 'MarshTit', 'MarshWarbler', 'MeadowPipit', 'NorthernLapwing', 'NorthernRaven', 'RedCrossbil', 'RedthroatedLoon', 'Redwing', 'RiverWarbler', 'RockDove', 'Rook', 'SedgeWarbler', 'SongThrush', 'SpottedFlycatcher', 'StockDove', 'TawnyOwl', 'TreePipit', 'WesternJackdaw', 'WesternYellowWagtail', 'WillowPtarmigan', 'WillowTit', 'WillowWarbler', 'WoodSandpiper', 'WoodWarbler', 'Yellowhammer']
# Training set has 6336 samples. X shape is (6336, 64, 64, 1)
# Test set has 1584 samples. X shape is (1584, 64, 64, 1)

# %%
[a.shape for a in [XX, y, X_train, X_test, y_train, y_test]]
# Out:
# [(264, 30, 64, 64, 1),
#  (7920,),
#  (6336, 64, 64, 1),
#  (1584, 64, 64, 1),
#  (6336,),
#  (1584,)]

# %%
show_melspectrogram(conf, XX[0, 0, :, :, -1], title=conf.labels[y[0]])
show_melspectrogram(conf, X_train[0, :, :, -1], title=conf.labels[y_train[0]])

# %%
print(conf.labels)
# Out:
# ['AfricanPiedWagtail', 'BarnSwallow', 'BlackWoodpecker', 'BlackheadedGull', 'CanadaGoose', 'CarrionCrow', 'CoalTit', 'CommonBlackbird', 'CommonChaffinch', 'CommonChiffchaff', 'CommonCuckoo', 'CommonHouseMartin', 'CommonLinnet', 'CommonMoorhen', 'CommonNightingale', 'CommonPheasant', 'CommonRedpoll', 'CommonRedshank', 'CommonRedstart', 'CommonReedBunting', 'CommonSnipe', 'CommonStarling', 'CommonSwift', 'CommonWhitethroat', 'CommonWoodPigeon', 'CornBunting', 'Dunlin', 'Dunnock', 'EurasianBlackcap', 'EurasianBlueTit', 'EurasianBullfinch', 'EurasianCollaredDove', 'EurasianCoot', 'EurasianGreenfinch', 'EurasianJay', 'EurasianMagpie', 'EurasianNuthatch', 'EurasianOystercatcher', 'EurasianReedWarbler', 'EurasianSkylark', 'EurasianTreeSparrow', 'EurasianTreecreeper', 'EurasianWren', 'EurasianWryneck', 'EuropeanBeeEater', 'EuropeanGoldenPlover', 'EuropeanGoldfinch', 'EuropeanGreenWoodpecker', 'EuropeanHerringGull', 'EuropeanHoneyBuzzard', 'EuropeanNightjar', 'EuropeanRobin', 'EuropeanTurtleDove', 'GardenWarbler', 'Goldcrest', 'GoldenOriole', 'GreatSpottedWoodpecker', 'GreatTit', 'GreyPartridge', 'GreyPlover', 'HouseSparrow', 'LesserWhitethroat', 'LongTailedTit', 'MarshTit', 'MarshWarbler', 'MeadowPipit', 'NorthernLapwing', 'NorthernRaven', 'RedCrossbil', 'RedthroatedLoon', 'Redwing', 'RiverWarbler', 'RockDove', 'Rook', 'SedgeWarbler', 'SongThrush', 'SpottedFlycatcher', 'StockDove', 'TawnyOwl', 'TreePipit', 'WesternJackdaw', 'WesternYellowWagtail', 'WillowPtarmigan', 'WillowTit', 'WillowWarbler', 'WoodSandpiper', 'WoodWarbler', 'Yellowhammer']
